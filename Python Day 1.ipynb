# %%
# i want to take input
# user input
# dont use user input
# add two number
a= 9
b=10
a+b
# Out:
# 19

# %%
a=input("enter the number=")
type(a)
# Out:
# enter the number= 9
# str

# %%
a=input("enter the no")
b=input("enter the no")
a+b
# Out:
# enter the no 9
# enter the no 15
# '915'

# %%
"hi "+" pyhton"
# Out:
# 'hi  pyhton'

# %%
a=int(input("enter the no."))
b=int(input("enter the no."))
c=a+b
print("The answer is",c)
# Out:
# enter the no. 15
# enter the no. 26
# The answer is 41

# %%
#take the user input 
# and multiply two no

a=int(input("enter the no:"))
b=int(input("enter the no:"))
c=a*b
print(c)
# Out:
# enter the no: 15
# enter the no: 94
# 1410

# %%
a=float(input("enter the no:"))
b=float(input("enter the no:"))
c=a*b
print("The answer is",c)
# Out:
# enter the no: 76.2
# enter the no: 954
# The answer is 72694.8

# %%
a=eval(input("enter the no:"))
b=eval(input("enter the no:"))
c=a*b
print("The answer is",c)
# Out:
# enter the no: 543
# enter the no: 45
# The answer is 24435

# %%
#u have to swap the number
a=9
b=6
#after swaping
#a=6
#b=9
a=a-b
b=b+a
a=b-a
print(a)
print(b)
# Out:
# 6
# 9

# %%
a=int(input("enter the input:"))
b=int(input("enter the input:"))
a=a-b
b=b+a
a=b-a
print("after swapping",a)
print("after swapping",b)
# Out:
# enter the input: 8
# enter the input: 12
# after swapping 12
# after swapping 8

# %% [markdown]
# a=9
# b=6
# a=a+b
# 9+6
# =15
# b=a-b
# =15-9
# =6
# #dryrun

# %%
#string
a="python"
#indexing
a[3]
# Out:
# 'h'

# %%
#p->0
#y->1
#t->2

# %%
#stringa
a="python"
#indexing
a[4]
# Out:
# 'o'

# %%
a="welcome to python"
# w->0
# e->1
# l->2
# c->3
# o->4
# m->5
# e->6
#spce -> 7
a[6]
# Out:
# 'e'

# %%
a="welcome to python"
# w->0
# e->1
# l->2
# c->3
# o->4
# m->5
# e->6
#spce -> 7
a[-9]
a[-5]

#negatve indexing start from the right begins with 1
#positive indexing start from the left begins with 0
# Out:
# 'y'

# %%
a="welcome to python"
a[0:7]
#to
# Out:
# 'welcome'

# %%
a="welcome to python"
a[8:10]
# Out:
# 'to'

# %%
a="welcome to python"
a[15:]
#after selceting from which num use : afte that no eveyitng will be displayed
#starting index
#end
#step
# Out:
# 'on'

# %%
a="welcome to python"
a[0:7]
# Out:
# 'welcome'

# %%
a="welcome to python"
a[0:7:2]
# Out:
# 'wloe'

# %%
a="welcome to python"
a[0:7:1]
# Out:
# 'welcome'

# %%
a="python"
#po
#ph
a[0:6:3]
a[0:6:4]
# Out:
# 'po'

# %%
a="python"
#po
#ph
a[0:6:5]
# Out:
# 'pn'

# %%
a="welcome to python"
#wy
a[0:16:12]
# Out:
# 'wy'

# %%
a="welcome to python"
#wy
#slicing using -ve indexing
#no
a[-1:-3:-1]
# Out:
# 'no'

# %%
a="welcome to python"
#slicing using -ve indexing #w=-17,e=-16,l=-15,c=-14,o=-13,m=-12,e=-11, =-10, t=-9 , o=-8 , =-7, p=-6, y=
#eomc
a[-11:-15:-1]
# Out:
# 'emoc'

# %%
a="welcome to python"
#slicing using -ve indexing #
#yt
a[-5:-2]
# Out:
# 'yth'

# %%
"welcome to python"
a[::]
# Out:
# 'welcome to python'

# %%
"welcome to python"
a[::-1]
# Out:
# 'nohtyp ot emoclew'

# %%
#inbuilt method in str
# i want to check the lenghth of the srting
len(a)
# Out:
# 17

# %%
min(a)
# Out:
# ' '

# %%
max(a)
# Out:
# 'y'

# %%
"delhi"=="delhi"
# Out:
# True

# %%
sorted(a)
# Out:
# [' ',
#  ' ',
#  'c',
#  'e',
#  'e',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'o',
#  'p',
#  't',
#  't',
#  'w',
#  'y']

# %%
sorted(a,reverse=True)
# Out:
# ['y',
#  'w',
#  't',
#  't',
#  'p',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  ' ',
#  ' ']

# %%
#user input
# done some program
#indexing
#swapping
#slicing
#len
#min
#max
#sorted

# %%
a="python"
a[::]
# Out:
# 'python'
