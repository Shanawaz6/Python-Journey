# %%
# i like python
# remove vowels in the above string*
# *l*k* pyth*n

t="i like python"
vowels="aeiouAEIOU"
result=""
for char in t:
    if char in vowels:
        result+="*"
    else:
        result+=char
print(result)
# Out:
# * l*k* pyth*n

# %% [markdown]
# # List

# %%
# list
# create the emptyu list
l=[]
type(l)
# Out:
# list

# %%
l=['ad','aks','ak','panda','pyhton','dog']
type(l)
# Out:
# list

# %%
l[3]
# Out:
# 'panda'

# %%
l[-4]
# Out:
# 'ak'

# %%
l[3:5]
# Out:
# ['panda', 'pyhton']

# %%
l=[1,4,5,"python",True,7+9j]
type(l)
# Out:
# list

# %%
l=[1,2,[3,4]]
type(l)
# Out:
# list

# %%
l[2]
# Out:
# [3, 4]

# %%
l[1]
# Out:
# 2

# %%
l[2][0]
# Out:
# 3

# %%
l[2][1]
# Out:
# 4

# %%
l=[1,2,[3,4,9,8,89]] #to find 89
l[2][4]
# Out:
# 89

# %%
l=[[[1,2],[3,4]],[[5,6],[7,8]]] #8
l[1][1][1]
# Out:
# 8

# %%
#6
l[1][0][1]
# Out:
# 6

# %%
#4
l[0][1][1]
# Out:
# 4

# %%
s="python"
s[0]="c"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 s="python"
# ----> 2 s[0]="c"
#
# TypeError: 'str' object does not support item assignment

# %%
l=[1,7,0,9,'pyhton']
# i will change 0 to 8.9
l[2]=8.9
l
# Out:
# [1, 7, 8.9, 9, 'pyhton']

# %% [markdown]
# ## sttrng is immutable we cant edit,indec wise
# ## list is mutable,we can edit

# %% [markdown]
# ## how to add the value

# %%
l=[1,7,0,9,'python']
l.extend('panda')  # extend it will add and take single letter and sepetare them
l
# Out:
# [1, 7, 0, 9, 'python', 'p', 'a', 'n', 'd', 'a']

# %%
l=[1,7,0,9,'python']
l.append('panda')  #append add total word
l
# Out:
# [1, 7, 0, 9, 'python', 'panda']

# %%
l=[1,7,0,9,'python']
l.append([5,6,7,89])
l
# Out:
# [1, 7, 0, 9, 'python', [5, 6, 7, 89]]

# %%
l=[1,7,0,9,'python']
l.extend([5,6,7,89])
l
# Out:
# [1, 7, 0, 9, 'python', 5, 6, 7, 89]

# %%
l=[1,7,0,9,'python']
l.extend(['python','panda','anaconda'])
l
# Out:
# [1, 7, 0, 9, 'python', 'python', 'panda', 'anaconda']

# %%
l=[1,7,0,9,'python']
l.append(['python','panda','anaconda'])
l
# Out:
# [1, 7, 0, 9, 'python', ['python', 'panda', 'anaconda']]

# %% [markdown]
# # insert

# %%
l=[1,6,7,9]
l.insert(1,60) # insert it add new numbers a/c to the index number given
l
# Out:
# [1, 60, 6, 7, 9]

# %%
l=[1,6,7,9]
l.insert(3,60) # insert it add new numbers a/c to the index number given
l
# Out:
# [1, 6, 7, 60, 9]

# %%
l=[1,6,7,9]
l.insert(3,91)
l
# Out:
# [1, 6, 7, 91, 9]

# %%
l=[1,6,7,91,9]
del l[1:3]
l
# Out:
# [1, 91, 9]

# %%
l=[1,'p','q','r',89,90,45]
del l[1:4]         #del pqr
l
# Out:
# [1, 89, 90, 45]

# %%
l=[1,'p','q','r',89,90,45]
l.remove(45)         #remove the specific elementl=
l
# Out:
# [1, 'p', 'q', 'r', 89, 90]

# %%
#pop

l=[1,89,90] #pop deletes last element
l.pop()
l
# Out:
# [1, 89]

# %%
l=[1,89,90] #clear deletes all things in the list
l.clear()
l
# Out:
# []

# %%
l=[1,89,90,'shanu'] #pop deletes last element
l.pop()
l
# Out:
# [1, 89, 90]

# %%
l=[1,2,3,4,-1,8]

print(len(l))
# Out:
# 6

# %%
print(min(l))
# Out:
# -1

# %%
print(max(l))
# Out:
# 8

# %%
print(sorted(l,reverse=False)) #false ascending
# Out:
# [-1, 1, 2, 3, 4, 8]

# %%
print(sorted(l))
# Out:
# [-1, 1, 2, 3, 4, 8]

# %%
l=[1,2,3,4,-1,8,9,97,0,9]
l.count(9)
# Out:
# 2

# %%
l=[1,2,3,4,-1,8,9,97,0,9]
l.index(9) 
#it will give 9 where it is present
# Out:
# 6

# %%
l=[1,2,3,4,-1,8,9,97,0,9]
l.reverse()

# %%
l[::-1]
# Out:
# [9, 0, 97, 9, 8, -1, 4, 3, 2, 1]

# %%
l=[1,2,3,4,-1,8,9,97,0,9]
l.reverse()
l
# Out:
# [9, 0, 97, 9, 8, -1, 4, 3, 2, 1]

# %%
l=[1,2,3,4,-1,8,9,97,0,9]
l.sort()
l
# Out:
# [-1, 0, 1, 2, 3, 4, 8, 9, 9, 97]

# %%
l=[1,2,3,4,-1,8,9,97,0,9]
sorted(l,reverse=True) # descending order
# Out:
# [97, 9, 9, 8, 4, 3, 2, 1, 0, -1]

# %%
l=[1,2,3,4,-1,8,9,97,0,9]
sorted(l)
# Out:
# [-1, 0, 1, 2, 3, 4, 8, 9, 9, 97]

# %%
l1=l.copy()
l1
# Out:
# [1, 2, 3, 4, -1, 8, 9, 97, 0, 9]

# %%
id(l)
# Out:
# 2297617601728

# %%
l1=[8,9,0]
l2=[8,7,5]
l1+l2
# Out:
# [8, 9, 0, 8, 7, 5]

# %%
l1=[8,9,0]
l2=[8,7,5]
l1*2
# Out:
# [8, 9, 0, 8, 9, 0]

# %%
l1=[8,9,0]
l2=[8,7,5]
l1*3
# Out:
# [8, 9, 0, 8, 9, 0, 8, 9, 0]

# %%
[i for i in range(1,10)]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
[i*i for i in range(1,10)]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
[i**i for i in range(1,10)]  

#  ** Power
# Out:
# [1, 4, 27, 256, 3125, 46656, 823543, 16777216, 387420489]

# %%
# 1 to 100
# number divisible by 5
[i*i for i in range(1,100) if i%5==0]
# Out:
# [25,
#  100,
#  225,
#  400,
#  625,
#  900,
#  1225,
#  1600,
#  2025,
#  2500,
#  3025,
#  3600,
#  4225,
#  4900,
#  5625,
#  6400,
#  7225,
#  8100,
#  9025]

# %%
# 1 to 100
# number divisible by 6
[i for i in range(1,100) if i%6==0]
# Out:
# [6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96]

# %% [markdown]
# # Tuples

# %%
t=()
type(t)
# Out:
# tuple

# %%
t=(9)
type(t)
# Out:
# int

# %%
t=[9]
type(t)
# Out:
# list

# %%
t=(9,)
type(t)
# Out:
# tuple

# %%
t=("python")
type(t)
,,
# Out:
# str

# %%
t=90,78,65,900
type(t)
# Out:
# tuple

# %%
t=(90,78,65,900)
type(t)
# Out:
# tuple

# %%
t=(9,8.9,'p',True)  # we can store both homogenous and hetrogeneous
t[3]
# Out:
# True

# %%
t[-1]
# Out:
# True

# %%
t=(9,8.9,'p',True,(9,0),[8,9])  
t[3]          # inside the tuple we can store the {nested tuples,list}
# Out:
# True

# %%
l=[8,9,0,(9,90)]
l[3][1]
# Out:
# 90

# %% [markdown]
# t=(3,7,9)
# # 9
# # 90
# # tuple is immutable because index wise we cant edit it

# %% [markdown]
# # convert tuple to list

# %%
l=list(t)
l
# Out:
# [9, 8.9, 'p', True, (9, 0)]

# %%
l=[9,8,78]
l1=tuple(l)
l1
# Out:
# (9, 8, 78)
