# %%
s="welcome to python"
#emocl
s[-11:-16:-1]
# Out:
# 'emocl'

# %%
s=124
#that number to string
s2=str(124)
type(s2)
# Out:
# str

# %%
len(s2)
# Out:
# 3

# %%
#arthematic op
"delhi"+"kolkota"
# Out:
# 'delhikolkota'

# %%
"kolkota "*3
# Out:
# 'kolkota kolkota kolkota '

# %%
"python"=="python"
# Out:
# True

# %%
"Python">"python"
# Out:
# False

# %%
"hi" and "python"
# Out:
# 'python'

# %%
"boxing" and "mma"
# Out:
# 'mma'

# %%
"boxing" or "mma"
# Out:
# 'boxing'

# %%
"da" or "ds"
# Out:
# 'da'

# %%
"da" or "ds"
# Out:
# 'da'

# %%
"" or "python"
# Out:
# 'python'

# %%
" " or "python"
# Out:
# ' '

# %%
"" and "python"
# Out:
# ''

# %%
" " and "python"
# Out:
# 'python'

# %%
"p" in "python"
# Out:
# True

# %%
"p" not in "python"
# Out:
# False

# %%
s="welcome to python"
len(s)
# Out:
# 17

# %%
min(s)
# Out:
# ' '

# %%
max(s)
# Out:
# 'y'

# %%
s="hi python"
s.capitalize()
# Out:
# 'Hi python'

# %%
s.title()
# Out:
# 'Hi Python'

# %%
s.upper()
# Out:
# 'HI PYTHON'

# %%
s.lower()
# Out:
# 'hi python'

# %%
sorted(s)#ascending
# Out:
# [' ', 'h', 'h', 'i', 'n', 'o', 'p', 't', 'y']

# %%
sorted(s,reverse=True)
# Out:
# ['w', 'o', 'm', 'l', 'e', 'e', 'c']

# %%
s="Welocme"
s.swapcase()
# Out:
# 'wELOCME'

# %% [markdown]
# #upper -> entire sentce will be capital
# #lower -> entire sent will be lower
# #capitalize -> only firstc letter from sentence
# #tille -> first letter from every word will become capital
# #swapcase -> capital will bceome samll and small become captial

# %%
#count # find  # index

# %%
s="welcome to python"
s.count('o')
# Out:
# 3

# %%
s="welcome to python"
s.count('m')
# Out:
# 1

# %%
s="welcome to python"
s.find('n')
# Out:
# 16

# %%
s="welcome to python"
s.find('w')
# Out:
# 0

# %%
s="welcome to python"
s.find('y')
# Out:
# 12

# %%
s="welcome to python"
s.find("z")
# Out:
# -1

# %%
s="welcome to python"
s.index("c")
# Out:
# 3

# %%
#index and find
#if char is not there index will
#give teh error
#find -1
#

# %% [markdown]
# # startswith

# %%
s="welcome to python"
s.startswith('s')
# Out:
# False

# %% [markdown]
# # endwith

# %%
s="welcome to python"
s.endswith('pn')
# Out:
# False

# %%
s="welcome to python"
s.endswith('on')
# Out:
# True

# %%
a="python123"
a.isalnum()
# Out:
# True

# %%
a="python#"
a.isalnum()
# Out:
# False

# %% [markdown]
# # isalpha - isalnum - isdigit - isidentifier

# %%
a="python"
a.isalnum()
# Out:
# True

# %%
a="123"
a.isalnum()


# alphabet
# numerical
# alpha numerical
#special char --> false
# Out:
# 3

# %%
a='75'
a.isalpha()
#only alphabet
# no space shukd be allowed - > false
# Out:
# False

# %%
a='shanu'
a.isalpha()
# Out:
# True

# %%
a='shanu75'
a.isalpha()
# Out:
# False

# %%
a='t y'
a.isalpha()
# Out:
# False

# %%
a="789"
a.isdigit()
# it wont allow spce
# it will take only numerical
# it will take only integer
# Out:
# True

# %%
a="789.9"
a.isdigit()
# Out:
# False

# %%
a="45a"
a.isidentifier()
# Out:
# False

# %%
a="_45"
a.isidentifier()
# we cant start with spcl character r no. r key words
# Out:
# True

# %%
a="false"
a.isidentifier()
# Out:
# True

# %%
a="where"
a.isidentifier()
# Out:
# True

# %%
a="#what"
a.isidentifier()
# Out:
# False

# %%
a="#7"
a.isidentifier()
# Out:
# False

# %%
a="_what"
a.isidentifier()
# Out:
# True

# %% [markdown]
# #islanum > both alphabet and number
# #isalpha > only alphabets
# #isdigti > only number
# #isidentifier > alpha numberical

# %%
a="ad89.0"
a.isalnum()
# Out:
# False

# %%
"my name is python". split()
# it divides each word with space and comas
# Out:
# ['my', 'name', 'is', 'python']

# %%
" ".join (['my', 'name', 'is', 'python'])
# Out:
# 'my name is python'

# %%
"my name is python" .replace('p','c')
# Out:
# 'my name is cython'

# %%
"my name is python" .replace('python','shanu')
# Out:
# 'my name is shanu'

# %%
"a             ".strip()
# Out:
# 'a'

# %%
"           a".lstrip()
# Out:
# 'a'

# %%
"a           ".rstrip()

#strip for remove space
#lstrip removes left hans spce
#rstrip removes right hand space
# Out:
# 'a'

# %% [markdown]
# # Format

# %%
a="python"
b="prog"
s="my name is {0}, i am {1}"
s.format(b,a)
# Out:
# 'my name is prog, i am python'

# %%
a="python"
b="prog"
s="my name is {1}, i am {0}"
s.format(b,a)
# Out:
# 'my name is python, i am prog'

# %%
a="python"
b="prog"
s="my name is {0}, i am {1}"
s.format(a,b)
#0 - python
# 1 - prog
# Out:
# 'my name is python, i am prog'

# %%
a="python"
b="prog"
s="my name is {0}, i am {1}"
s.format(b,a)
# Out:
# 'my name is prog, i am python'

# %%
a='boxing'
b='sports'
f'my name is {a} it is {b}'
# Out:
# 'my name is boxing it is sports'

# %% [markdown]
# # conditional statememt

# %%
a=9
if a>5:
    print("yes")
# Out:
# yes

# %%
a=9
if a>59:
    print("yes")
else:
    print("No")
# Out:
# No

# %%
age=int(input())
if age>18:
    print("go to college")
else:
    print("go to work")
# Out:
#  12
# go to work

# %%
age=int(input())
if age>18:
    print("go to college")
else:
    print("go to work")
# Out:
#  25
# go to college

# %%
age=int(input())
if age>18 and age <=23:
    print("go to college")
else:
    print("go to work")
# Out:
#  22
# go to college

# %%
age=int(input())
if age>18 and age <=23:
    print("go to college")
else:
    print("school")

# %%
#check the number is even or odd
n=int(input())
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
#  26
# even

# %%
#check the number is even or odd
n=int(input())
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
#  89
# odd

# %%
#check the number is even or odd
n=int(input())
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
#  25
# odd
